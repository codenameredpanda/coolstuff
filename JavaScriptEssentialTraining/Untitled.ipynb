# %%
import pandas as pd

# %%
crimedf = pd.read_csv('Individual_Incident_2022.csv')
crimedf.head()
# Out:
# C:\Users\sgbri\AppData\Local\Temp\ipykernel_24548\1237465259.py:1: DtypeWarning: Columns (52) have mixed types. Specify dtype option on import or set low_memory=False.
#   crimedf = pd.read_csv('Individual_Incident_2022.csv')
#        state                      ID        ORI incident_number  date_HRF  \
# 0  AK-Alaska  AK0010200_0G1A0BRVSCTD  AK0010200    0G1A0BRVSCTD  20220625
# 1  AK-Alaska  AK0010200_0G1G0BRVSCTD  AK0010200    0G1G0BRVSCTD  20220713
# 2  AK-Alaska  AK0010200_0G1K0BRVSCTD  AK0010200    0G1K0BRVSCTD  20220702
# 3  AK-Alaska  AK0010200_0G1N0BRVSCTD  AK0010200    0G1N0BRVSCTD  20220711
# 4  AK-Alaska  AK0010200_0G9A0BRVSCTD  AK0010200    0G9A0BRVSCTD  20220526
#
#     date_SIF hour  total_offense  total_victim  total_offender  ...  \
# 0  25jun2022  NaN            NaN           NaN             NaN  ...
# 1  13jul2022  NaN            NaN           NaN             NaN  ...
# 2  02jul2022  NaN            NaN           NaN             NaN  ...
# ...
